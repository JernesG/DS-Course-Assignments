# %% [markdown]
# EDA1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading data
data = pd.read_csv("Cardiotocographic.csv")
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#By using the below comment we can see and verify the datatypes of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
#Identifying the missing values in the data

data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
#Finding median for each columns to fill null values

Median_LB = data["LB"].median()
Median_AC = data["AC"].median()
Median_DS = data["DS"].median()
Median_DP = data["DP"].median()
Median_MLTV = data["MLTV"].median()
Median_Width = data["Width"].median()
Median_Tendency = data["Tendency"].median()
Median_NSP = data["NSP"].median()


#Fill column_median values in the null values on the each columns

data["LB"] = data["LB"].fillna(Median_LB)
data["AC"] = data["AC"].fillna(Median_AC)
data["DS"] = data["DS"].fillna(Median_DS)
data["DP"] = data["DP"].fillna(Median_DP)
data["MLTV"] = data["MLTV"].fillna(Median_MLTV)
data["Width"] = data["LB"].fillna(Median_Width)
data["Tendency"] = data["LB"].fillna(Median_Tendency)
data["NSP"] = data["LB"].fillna(Median_NSP)

#Checking again the null count on each row to verify whether the median value is filled or not
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
#Checking for duplicates in the table

data[data.duplicated(keep= False)]
# Out:
#          LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 67    140.0  0.007278  0.000000  0.004367  0.000000  0.0  0.000000  34.0
# 68    140.0  0.007278  0.000000  0.004367  0.000000  0.0  0.000000  34.0
# 790   123.0  0.002660  0.003989  0.000000  0.000000  0.0  0.000000  50.0
# 791   123.0  0.002660  0.003989  0.000000  0.000000  0.0  0.000000  50.0
# 1113  122.0  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  19.0
# 1115  122.0  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  19.0
# 1380  121.0  0.000000  0.000000  0.003478  0.005217  0.0  0.001739  24.0
# 1381  121.0  0.000000  0.000000  0.003478  0.005217  0.0  0.001739  24.0
# 1457  148.0  0.004717  0.000000  0.002358  0.000000  0.0  0.000000  40.0
# 1458  148.0  0.004717  0.000000  0.002358  0.000000  0.0  0.000000  40.0
#
#       MSTV  ALTV  MLTV  Width  Tendency    NSP
# 67     1.2   0.0  10.3  140.0     140.0  140.0
# 68     1.2   0.0  10.3  140.0     140.0  140.0
# ...

# %%
#Droping duplicate rows
data = data.drop_duplicates(keep = 'first')

# %%
#Checking again is there any duplicate rows are present
data[data.duplicated(keep= False)]
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV, Width, Tendency, NSP]
# Index: []

# %%
#Detecting Outliers

#We can find the outliers by Many methods like Z-score values,IQR methods and Visualization

#IQR methods
# Calculate Q1 and Q3
Q1_LB=np.percentile((data["LB"]),25)
Q3_LB=np.percentile((data["LB"]),75)

# Calculate IQR
IQR = Q3_LB - Q1_LB

# Determine outlier boundaries
lower_bound = Q1_LB - 1.5 * IQR
upper_bound = Q3_LB + 1.5 * IQR

print("Q1:", Q1_LB)
print("Q3:", Q3_LB)
print("IQR:", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Identify outliers
for x in data["LB"]:
    if (x<lower_bound):
        print("Lower Outliers:",x)
    elif (x>upper_bound):
        print("Upper Outliers:",x)
# Out:
# Q1: 126.0
# Q3: 140.0
# IQR: 14.0
# Lower Bound: 105.0
# Upper Bound: 161.0
# Lower Outliers: 52.0
# Upper Outliers: 214.0
# Upper Outliers: 214.0
# Upper Outliers: 214.0
# Lower Outliers: 52.0
# Lower Outliers: 51.84248683343552
# Upper Outliers: 214.0
# Upper Outliers: 214.0
# Upper Outliers: 214.0
# Lower Outliers: 52.18854680260237

# %%
#Data Visualization:

#Boxplot
Boxplot_LB=plt.boxplot(data["LB"],vert=False)

# %%
#We can find the outliers form boxplot also

#To get outliers values on LB column

[item.get_xdata() for item in Boxplot_LB['fliers']]
# Out:
# [array([ 52.        ,  52.        ,  51.84248683,  52.1885468 ,
#         214.        , 214.        , 214.        , 214.        ,
#         214.        , 214.        ])]

# %%
#We are getting same value from IQR and Boxplot visual value and also in finding values

#In the given data we are only having numerical data we can't use bar charts

# %%
#Scatter plots to explore relationships between pairs of variables.

#Lets randomly plot Scatter plot between two variables

plt.scatter(data["LB"], data["NSP"])
# The below one is perfect positive linear correlation

# %%
plt.scatter(data["MSTV"], data["DL"])
# The below one is modurate positive linear correlation

# %%
plt.scatter(data["NSP"], data["UC"])
# The below one is negative modurate linear correlation

# %%
#Pair plot

#Pair plot is also same like scatter plot only. It will give visulalization of combination of all columns in the table
#In simple word we can say scatter matrix.

#To plot pair plot for the data

sns.pairplot(data.iloc[:,0:7])
S
#Here i have done the pairplot from 1 to 8 column only. we have do for all columns also.
#Using this we can find the relationship patterns between the two numerical data.
#In pairplot the left to right plot will be always histogram only. becoz both comparing columns are same.
# Out:
# C:\Users\gjernes\AppData\Local\anaconda3_\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gjernes\AppData\Local\anaconda3_\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\gjernes\AppData\Local\anaconda3_\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#Without do ploting also we can find the correleation values for two or all combination of data in the table.

# %%
data.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.064178  0.018777 -0.167547 -0.126278 -0.005448
# AC       -0.064178  1.000000  0.009755  0.071199 -0.093090 -0.033107
# FM        0.018777  0.009755  1.000000 -0.053483  0.009651  0.029912
# UC       -0.167547  0.071199 -0.053483  1.000000  0.189665 -0.006974
# DL       -0.126278 -0.093090  0.009651  0.189665  1.000000  0.058434
# DS       -0.005448 -0.033107  0.029912 -0.006974  0.058434  1.000000
# DP       -0.046780 -0.082723  0.121645  0.070346  0.143821  0.004333
# ASTV      0.241546 -0.231382 -0.032980 -0.182606 -0.069537  0.008404
# MSTV     -0.169487  0.133344  0.017044  0.189543  0.410194  0.016025
# ALTV      0.210671 -0.270065 -0.012086 -0.228257 -0.187353 -0.004355
# MLTV     -0.003455 -0.105152 -0.006064 -0.048511 -0.164377  0.034400
# Width     1.000000 -0.064178  0.018777 -0.167547 -0.126278 -0.005448
# Tendency  1.000000 -0.064178  0.018777 -0.167547 -0.126278 -0.005448
# ...

# %%
|
